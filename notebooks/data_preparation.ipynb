# %% [markdown]
# # Setup

# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', lambda x: '%.4f' % x)

# %% [markdown]
# # Read data

# %%
locations = [
    {
        'city': 'los_angeles',
        'state': 'california',
        'country': 'united_states'
    },
    {
        'city': 'san_diego',
        'state': 'california',
        'country': 'united_states'
    },
    {
        'city': 'chicago',
        'state': 'illinois',
        'country': 'united_states'
    },
    {
        'city': 'austin',
        'state': 'texas',
        'country': 'united_states'
    },
    {
        'city': 'dallas',
        'state': 'texas',
        'country': 'united_states'
    }
]

raw_df = pd.DataFrame()
for location in locations:
    aux_df = pd.read_csv(f"../data/raw/listings-{location['country']}-{location['state']}-{location['city']}.csv.gz",
                         compression='gzip')
    
    aux_df['country'] = location['country']
    aux_df['state'] = location['state']
    aux_df['city'] = location['city']

    raw_df = pd.concat([aux_df,  raw_df])

# %% [markdown]
# # Data profiling

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 86295 entries, 0 to 45532
# Data columns (total 78 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            86295 non-null  int64
#  1   listing_url                                   86295 non-null  object
#  2   scrape_id                                     86295 non-null  int64
#  3   last_scraped                                  86295 non-null  object
#  4   source                                        86295 non-null  object
#  5   name                                          86294 non-null  object
#  6   description                                   83816 non-null  object
#  7   neighborhood_overview                         48031 non-null  object
#  8   picture_url                                   86294 non-null  object
#  9   host_id                                       86295 non-null  int64
#  10  host_url                                      86295 non-null  object
#  11  host_name                                     86291 non-null  object
#  12  host_since                                    86291 non-null  object
#  13  host_location                                 67617 non-null  object
#  14  host_about                                    49912 non-null  object
#  15  host_response_time                            70406 non-null  object
#  16  host_response_rate                            70406 non-null  object
#  17  host_acceptance_rate                          71810 non-null  object
#  18  host_is_superhost                             83716 non-null  object
#  19  host_thumbnail_url                            86291 non-null  object
#  20  host_picture_url                              86291 non-null  object
#  21  host_neighbourhood                            73269 non-null  object
#  22  host_listings_count                           86291 non-null  float64
#  23  host_total_listings_count                     86291 non-null  float64
#  24  host_verifications                            86291 non-null  object
#  25  host_has_profile_pic                          86291 non-null  object
#  26  host_identity_verified                        86291 non-null  object
#  27  neighbourhood                                 48033 non-null  object
#  28  neighbourhood_cleansed                        86295 non-null  object
#  29  neighbourhood_group_cleansed                  45533 non-null  object
#  30  latitude                                      86295 non-null  float64
#  31  longitude                                     86295 non-null  float64
#  32  property_type                                 86295 non-null  object
#  33  room_type                                     86295 non-null  object
#  34  accommodates                                  86295 non-null  int64
#  35  bathrooms                                     72734 non-null  float64
#  36  bathrooms_text                                86241 non-null  object
#  37  bedrooms                                      82064 non-null  float64
#  38  beds                                          72531 non-null  float64
#  39  amenities                                     86295 non-null  object
#  40  price                                         72739 non-null  object
#  41  minimum_nights                                86295 non-null  int64
#  42  maximum_nights                                86295 non-null  int64
#  43  minimum_minimum_nights                        86288 non-null  float64
#  44  maximum_minimum_nights                        86288 non-null  float64
#  45  minimum_maximum_nights                        86288 non-null  float64
#  46  maximum_maximum_nights                        86288 non-null  float64
#  47  minimum_nights_avg_ntm                        86288 non-null  float64
#  48  maximum_nights_avg_ntm                        86288 non-null  float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              81488 non-null  object
#  51  availability_30                               86295 non-null  int64
#  52  availability_60                               86295 non-null  int64
#  53  availability_90                               86295 non-null  int64
#  54  availability_365                              86295 non-null  int64
#  55  calendar_last_scraped                         86295 non-null  object
#  56  number_of_reviews                             86295 non-null  int64
#  57  number_of_reviews_ltm                         86295 non-null  int64
#  58  number_of_reviews_l30d                        86295 non-null  int64
#  59  first_review                                  66855 non-null  object
#  60  last_review                                   66855 non-null  object
#  61  review_scores_rating                          66855 non-null  float64
#  62  review_scores_accuracy                        66810 non-null  float64
#  63  review_scores_cleanliness                     66809 non-null  float64
#  64  review_scores_checkin                         66801 non-null  float64
#  65  review_scores_communication                   66809 non-null  float64
#  66  review_scores_location                        66798 non-null  float64
#  67  review_scores_value                           66798 non-null  float64
#  68  license                                       28912 non-null  object
#  69  instant_bookable                              86295 non-null  object
#  70  calculated_host_listings_count                86295 non-null  int64
#  71  calculated_host_listings_count_entire_homes   86295 non-null  int64
#  72  calculated_host_listings_count_private_rooms  86295 non-null  int64
#  73  calculated_host_listings_count_shared_rooms   86295 non-null  int64
#  74  reviews_per_month                             66855 non-null  float64
#  75  country                                       86295 non-null  object
#  76  state                                         86295 non-null  object
#  77  city                                          86295 non-null  object
# dtypes: float64(22), int64(17), object(39)
# memory usage: 52.0+ MB

# %%
raw_df.dtypes.unique()
# Out:
# array([dtype('int64'), dtype('O'), dtype('float64')], dtype=object)

# %%
raw_df.describe(include=['int64','float64'], percentiles=np.arange(0.1,1,0.1)).T
# Out:
#                                                   count  \
# id                                           86295.0000
# scrape_id                                    86295.0000
# host_id                                      86295.0000
# host_listings_count                          86291.0000
# host_total_listings_count                    86291.0000
# latitude                                     86295.0000
# longitude                                    86295.0000
# accommodates                                 86295.0000
# bathrooms                                    72734.0000
# bedrooms                                     82064.0000
# beds                                         72531.0000
# minimum_nights                               86295.0000
# maximum_nights                               86295.0000
# minimum_minimum_nights                       86288.0000
# maximum_minimum_nights                       86288.0000
# minimum_maximum_nights                       86288.0000
# maximum_maximum_nights                       86288.0000
# minimum_nights_avg_ntm                       86288.0000
# maximum_nights_avg_ntm                       86288.0000
# calendar_updated                                 0.0000
# availability_30                              86295.0000
# availability_60                              86295.0000
# availability_90                              86295.0000
# availability_365                             86295.0000
# number_of_reviews                            86295.0000
# number_of_reviews_ltm                        86295.0000
# number_of_reviews_l30d                       86295.0000
# review_scores_rating                         66855.0000
# review_scores_accuracy                       66810.0000
# review_scores_cleanliness                    66809.0000
# review_scores_checkin                        66801.0000
# review_scores_communication                  66809.0000
# review_scores_location                       66798.0000
# review_scores_value                          66798.0000
# calculated_host_listings_count               86295.0000
# calculated_host_listings_count_entire_homes  86295.0000
# calculated_host_listings_count_private_rooms 86295.0000
# calculated_host_listings_count_shared_rooms  86295.0000
# reviews_per_month                            66855.0000
#
#                                                                 mean  \
# id                                           518906529884265280.0000
# scrape_id                                        20240834316409.4180
# host_id                                               190077911.3002
# host_listings_count                                         121.5143
# host_total_listings_count                                   163.7323
# latitude                                                     33.8515
# longitude                                                  -110.3930
# accommodates                                                  4.4310
# bathrooms                                                     1.6351
# bedrooms                                                      1.8692
# beds                                                          2.4395
# minimum_nights                                               14.2472
# maximum_nights                                              473.0621
# minimum_minimum_nights                                       13.7382
# maximum_minimum_nights                                       19.2075
# minimum_maximum_nights                                  1294784.8428
# maximum_maximum_nights                                  1568578.2408
# minimum_nights_avg_ntm                                       14.6267
# maximum_nights_avg_ntm                                  1533094.8483
# calendar_updated                                                 NaN
# availability_30                                              13.4166
# availability_60                                              30.6158
# availability_90                                              50.5519
# availability_365                                            192.5226
# number_of_reviews                                            43.0719
# number_of_reviews_ltm                                        10.5817
# number_of_reviews_l30d                                        0.8926
# review_scores_rating                                          4.7906
# review_scores_accuracy                                        4.8147
# review_scores_cleanliness                                     4.7656
# review_scores_checkin                                         4.8653
# review_scores_communication                                   4.8683
# review_scores_location                                        4.7981
# review_scores_value                                           4.7159
# calculated_host_listings_count                               19.0407
# calculated_host_listings_count_entire_homes                  16.9907
# calculated_host_listings_count_private_rooms                  1.4197
# calculated_host_listings_count_shared_rooms                   0.2129
# reviews_per_month                                             1.6208
#
#                                                                  std  \
# id                                           488638880166618240.0000
# scrape_id                                             119151661.3292
# host_id                                               187002790.2394
# host_listings_count                                         634.4123
# host_total_listings_count                                   783.7427
# latitude                                                      2.9118
# longitude                                                    11.2583
# accommodates                                                  3.1185
# bathrooms                                                     1.1096
# bedrooms                                                      1.3557
# beds                                                          2.1656
# minimum_nights                                               27.9443
# maximum_nights                                              422.0840
# minimum_minimum_nights                                       27.1698
# maximum_minimum_nights                                       48.1256
# minimum_maximum_nights                                 52702088.1650
# maximum_maximum_nights                                 58005439.1610
# minimum_nights_avg_ntm                                       28.0270
# maximum_nights_avg_ntm                                 57014029.2734
# calendar_updated                                                 NaN
# availability_30                                              11.6643
# availability_60                                              22.6506
# availability_90                                              33.3452
# availability_365                                            130.1593
# number_of_reviews                                            87.5510
# number_of_reviews_ltm                                        18.2536
# number_of_reviews_l30d                                        1.6920
# review_scores_rating                                          0.3834
# review_scores_accuracy                                        0.3672
# review_scores_cleanliness                                     0.4014
# review_scores_checkin                                         0.3307
# review_scores_communication                                   0.3394
# review_scores_location                                        0.3515
# review_scores_value                                           0.4175
# calculated_host_listings_count                               66.2450
# calculated_host_listings_count_entire_homes                  65.9797
# calculated_host_listings_count_private_rooms                  5.8628
# calculated_host_listings_count_shared_rooms                   2.5893
# reviews_per_month                                             1.8213
#
#                                                              min  \
# id                                                        6.0000
# scrape_id                                    20240621025845.0000
# host_id                                                  23.0000
# host_listings_count                                       0.0000
# host_total_listings_count                                 0.0000
# latitude                                                 30.0784
# longitude                                              -118.9171
# accommodates                                              1.0000
# bathrooms                                                 0.0000
# bedrooms                                                  0.0000
# beds                                                      0.0000
# minimum_nights                                            1.0000
# maximum_nights                                            1.0000
# minimum_minimum_nights                                    1.0000
# maximum_minimum_nights                                    1.0000
# minimum_maximum_nights                                    1.0000
# maximum_maximum_nights                                    1.0000
# minimum_nights_avg_ntm                                    1.0000
# maximum_nights_avg_ntm                                    1.0000
# calendar_updated                                             NaN
# availability_30                                           0.0000
# availability_60                                           0.0000
# availability_90                                           0.0000
# availability_365                                          0.0000
# number_of_reviews                                         0.0000
# number_of_reviews_ltm                                     0.0000
# number_of_reviews_l30d                                    0.0000
# review_scores_rating                                      0.0000
# review_scores_accuracy                                    0.0000
# review_scores_cleanliness                                 0.0000
# review_scores_checkin                                     0.0000
# review_scores_communication                               0.0000
# review_scores_location                                    0.0000
# review_scores_value                                       0.0000
# calculated_host_listings_count                            1.0000
# calculated_host_listings_count_entire_homes               0.0000
# calculated_host_listings_count_private_rooms              0.0000
# calculated_host_listings_count_shared_rooms               0.0000
# reviews_per_month                                         0.0100
#
#                                                              10%  \
# id                                                 14430280.4000
# scrape_id                                    20240624164233.0000
# host_id                                             5943134.4000
# host_listings_count                                       1.0000
# host_total_listings_count                                 1.0000
# latitude                                                 30.2747
# longitude                                              -118.4453
# accommodates                                              2.0000
# bathrooms                                                 1.0000
# bedrooms                                                  1.0000
# beds                                                      1.0000
# minimum_nights                                            1.0000
# maximum_nights                                           28.0000
# minimum_minimum_nights                                    1.0000
# maximum_minimum_nights                                    1.0000
# minimum_maximum_nights                                   29.0000
# maximum_maximum_nights                                   30.0000
# minimum_nights_avg_ntm                                    1.0000
# maximum_nights_avg_ntm                                   30.0000
# calendar_updated                                             NaN
# availability_30                                           0.0000
# availability_60                                           0.0000
# availability_90                                           0.0000
# availability_365                                          0.0000
# number_of_reviews                                         0.0000
# number_of_reviews_ltm                                     0.0000
# number_of_reviews_l30d                                    0.0000
# review_scores_rating                                      4.5000
# review_scores_accuracy                                    4.5600
# review_scores_cleanliness                                 4.4300
# review_scores_checkin                                     4.6700
# review_scores_communication                               4.6700
# review_scores_location                                    4.5000
# review_scores_value                                       4.4000
# calculated_host_listings_count                            1.0000
# calculated_host_listings_count_entire_homes               0.0000
# calculated_host_listings_count_private_rooms              0.0000
# calculated_host_listings_count_shared_rooms               0.0000
# reviews_per_month                                         0.0900
#
#                                                              20%  \
# id                                                 27694820.6000
# scrape_id                                    20240624164233.0000
# host_id                                            18361158.8000
# host_listings_count                                       1.0000
# host_total_listings_count                                 1.0000
# latitude                                                 32.7153
# longitude                                              -118.3749
# accommodates                                              2.0000
# bathrooms                                                 1.0000
# bedrooms                                                  1.0000
# beds                                                      1.0000
# minimum_nights                                            1.0000
# maximum_nights                                           60.0000
# minimum_minimum_nights                                    1.0000
# maximum_minimum_nights                                    2.0000
# minimum_maximum_nights                                  100.0000
# maximum_maximum_nights                                  180.0000
# minimum_nights_avg_ntm                                    2.0000
# maximum_nights_avg_ntm                                  180.0000
# calendar_updated                                             NaN
# availability_30                                           0.0000
# availability_60                                           0.0000
# availability_90                                           4.0000
# availability_365                                         48.0000
# number_of_reviews                                         0.0000
# number_of_reviews_ltm                                     0.0000
# number_of_reviews_l30d                                    0.0000
# review_scores_rating                                      4.6900
# review_scores_accuracy                                    4.7400
# review_scores_cleanliness                                 4.6600
# review_scores_checkin                                     4.8300
# review_scores_communication                               4.8300
# review_scores_location                                    4.7000
# review_scores_value                                       4.6000
# calculated_host_listings_count                            1.0000
# calculated_host_listings_count_entire_homes               1.0000
# calculated_host_listings_count_private_rooms              0.0000
# calculated_host_listings_count_shared_rooms               0.0000
# reviews_per_month                                         0.2100
#
#                                                              30%  \
# id                                                 41935631.8000
# scrape_id                                    20240904164210.0000
# host_id                                            36534353.0000
# host_listings_count                                       1.0000
# host_total_listings_count                                 2.0000
# latitude                                                 32.7923
# longitude                                              -118.3213
# accommodates                                              2.0000
# bathrooms                                                 1.0000
# bedrooms                                                  1.0000
# beds                                                      1.0000
# minimum_nights                                            2.0000
# maximum_nights                                          150.0000
# minimum_minimum_nights                                    2.0000
# maximum_minimum_nights                                    2.0000
# minimum_maximum_nights                                  365.0000
# maximum_maximum_nights                                  365.0000
# minimum_nights_avg_ntm                                    2.0000
# maximum_nights_avg_ntm                                  365.0000
# calendar_updated                                             NaN
# availability_30                                           2.0000
# availability_60                                          12.0000
# availability_90                                          30.0000
# availability_365                                         90.0000
# number_of_reviews                                         2.0000
# number_of_reviews_ltm                                     0.0000
# number_of_reviews_l30d                                    0.0000
# review_scores_rating                                      4.7900
# review_scores_accuracy                                    4.8200
# review_scores_cleanliness                                 4.7500
# review_scores_checkin                                     4.8900
# review_scores_communication                               4.9000
# review_scores_location                                    4.8000
# review_scores_value                                       4.7000
# calculated_host_listings_count                            1.0000
# calculated_host_listings_count_entire_homes               1.0000
# calculated_host_listings_count_private_rooms              0.0000
# calculated_host_listings_count_shared_rooms               0.0000
# reviews_per_month                                         0.3700
#
#                                                              40%  \
# id                                                 51521660.6000
# scrape_id                                    20240904164210.0000
# host_id                                            67108209.0000
# host_listings_count                                       2.0000
# host_total_listings_count                                 3.0000
# latitude                                                 33.7781
# longitude                                              -118.2235
# accommodates                                              3.0000
# bathrooms                                                 1.0000
# bedrooms                                                  1.0000
# beds                                                      1.0000
# minimum_nights                                            2.0000
# maximum_nights                                          365.0000
# minimum_minimum_nights                                    2.0000
# maximum_minimum_nights                                    3.0000
# minimum_maximum_nights                                  365.0000
# maximum_maximum_nights                                  365.0000
# minimum_nights_avg_ntm                                    2.3000
# maximum_nights_avg_ntm                                  365.0000
# calendar_updated                                             NaN
# availability_30                                           7.0000
# availability_60                                          24.0000
# availability_90                                          46.0000
# availability_365                                        150.0000
# number_of_reviews                                         4.0000
# number_of_reviews_ltm                                     1.0000
# number_of_reviews_l30d                                    0.0000
# review_scores_rating                                      4.8500
# review_scores_accuracy                                    4.8800
# review_scores_cleanliness                                 4.8300
# review_scores_checkin                                     4.9300
# review_scores_communication                               4.9400
# review_scores_location                                    4.8600
# review_scores_value                                       4.7600
# calculated_host_listings_count                            2.0000
# calculated_host_listings_count_entire_homes               1.0000
# calculated_host_listings_count_private_rooms              0.0000
# calculated_host_listings_count_shared_rooms               0.0000
# reviews_per_month                                         0.6500
#
#                                                                  50%  \
# id                                           642623748905205376.0000
# scrape_id                                        20240904164210.0000
# host_id                                               110271788.0000
# host_listings_count                                           3.0000
# host_total_listings_count                                     5.0000
# latitude                                                     33.9924
# longitude                                                  -117.9794
# accommodates                                                  4.0000
# bathrooms                                                     1.0000
# bedrooms                                                      1.0000
# beds                                                          2.0000
# minimum_nights                                                3.0000
# maximum_nights                                              365.0000
# minimum_minimum_nights                                        2.0000
# maximum_minimum_nights                                        4.0000
# minimum_maximum_nights                                      365.0000
# maximum_maximum_nights                                      365.0000
# minimum_nights_avg_ntm                                        3.0000
# maximum_nights_avg_ntm                                      365.0000
# calendar_updated                                                 NaN
# availability_30                                              12.0000
# availability_60                                              33.0000
# availability_90                                              58.0000
# availability_365                                            195.0000
# number_of_reviews                                             9.0000
# number_of_reviews_ltm                                         2.0000
# number_of_reviews_l30d                                        0.0000
# review_scores_rating                                          4.9000
# review_scores_accuracy                                        4.9200
# review_scores_cleanliness                                     4.8900
# review_scores_checkin                                         4.9600
# review_scores_communication                                   4.9700
# review_scores_location                                        4.9000
# review_scores_value                                           4.8200
# calculated_host_listings_count                                2.0000
# calculated_host_listings_count_entire_homes                   1.0000
# calculated_host_listings_count_private_rooms                  0.0000
# calculated_host_listings_count_shared_rooms                   0.0000
# reviews_per_month                                             1.0000
#
#                                                                  60%  \
# id                                           794457787092769152.0000
# scrape_id                                        20240904164210.0000
# host_id                                               178113872.0000
# host_listings_count                                           5.0000
# host_total_listings_count                                     8.0000
# latitude                                                     34.0470
# longitude                                                  -117.1773
# accommodates                                                  4.0000
# bathrooms                                                     1.5000
# bedrooms                                                      2.0000
# beds                                                          2.0000
# minimum_nights                                                5.0000
# maximum_nights                                              365.0000
# minimum_minimum_nights                                        4.0000
# maximum_minimum_nights                                        7.0000
# minimum_maximum_nights                                     1125.0000
# maximum_maximum_nights                                     1125.0000
# minimum_nights_avg_ntm                                        6.3000
# maximum_nights_avg_ntm                                     1125.0000
# calendar_updated                                                 NaN
# availability_30                                              17.0000
# availability_60                                              41.0000
# availability_90                                              68.0000
# availability_365                                            258.0000
# number_of_reviews                                            17.0000
# number_of_reviews_ltm                                         5.0000
# number_of_reviews_l30d                                        0.0000
# review_scores_rating                                          4.9400
# review_scores_accuracy                                        4.9600
# review_scores_cleanliness                                     4.9300
# review_scores_checkin                                         4.9900
# review_scores_communication                                   5.0000
# review_scores_location                                        4.9400
# review_scores_value                                           4.8600
# calculated_host_listings_count                                4.0000
# calculated_host_listings_count_entire_homes                   2.0000
# calculated_host_listings_count_private_rooms                  0.0000
# calculated_host_listings_count_shared_rooms                   0.0000
# reviews_per_month                                             1.5100
#
#                                                                  70%  \
# id                                           930320238454953472.0000
# scrape_id                                        20240904164210.0000
# host_id                                               283808397.8000
# host_listings_count                                          10.0000
# host_total_listings_count                                    15.0000
# latitude                                                     34.0831
# longitude                                                   -97.7847
# accommodates                                                  6.0000
# bathrooms                                                     2.0000
# bedrooms                                                      2.0000
# beds                                                          3.0000
# minimum_nights                                               30.0000
# maximum_nights                                              365.0000
# minimum_minimum_nights                                       30.0000
# maximum_minimum_nights                                       30.0000
# minimum_maximum_nights                                     1125.0000
# maximum_maximum_nights                                     1125.0000
# minimum_nights_avg_ntm                                       30.0000
# maximum_nights_avg_ntm                                     1125.0000
# calendar_updated                                                 NaN
# availability_30                                              23.0000
# availability_60                                              50.0000
# availability_90                                              78.0000
# availability_365                                            301.0000
# number_of_reviews                                            33.0000
# number_of_reviews_ltm                                        10.0000
# number_of_reviews_l30d                                        1.0000
# review_scores_rating                                          5.0000
# review_scores_accuracy                                        5.0000
# review_scores_cleanliness                                     4.9800
# review_scores_checkin                                         5.0000
# review_scores_communication                                   5.0000
# review_scores_location                                        4.9900
# review_scores_value                                           4.9100
# calculated_host_listings_count                                7.0000
# calculated_host_listings_count_entire_homes                   5.0000
# calculated_host_listings_count_private_rooms                  0.0000
# calculated_host_listings_count_shared_rooms                   0.0000
# reviews_per_month                                             2.1000
#
#                                                                   80%  \
# id                                           1047445635630221312.0000
# scrape_id                                         20240904164210.0000
# host_id                                                414861542.0000
# host_listings_count                                           22.0000
# host_total_listings_count                                     32.0000
# latitude                                                      34.1276
# longitude                                                    -97.7184
# accommodates                                                   6.0000
# bathrooms                                                      2.0000
# bedrooms                                                       3.0000
# beds                                                           4.0000
# minimum_nights                                                30.0000
# maximum_nights                                              1125.0000
# minimum_minimum_nights                                        30.0000
# maximum_minimum_nights                                        30.0000
# minimum_maximum_nights                                      1125.0000
# maximum_maximum_nights                                      1125.0000
# minimum_nights_avg_ntm                                        30.0000
# maximum_nights_avg_ntm                                      1125.0000
# calendar_updated                                                  NaN
# availability_30                                               28.0000
# availability_60                                               57.0000
# availability_90                                               87.0000
# availability_365                                             338.0000
# number_of_reviews                                             62.0000
# number_of_reviews_ltm                                         20.0000
# number_of_reviews_l30d                                         2.0000
# review_scores_rating                                           5.0000
# review_scores_accuracy                                         5.0000
# review_scores_cleanliness                                      5.0000
# review_scores_checkin                                          5.0000
# review_scores_communication                                    5.0000
# review_scores_location                                         5.0000
# review_scores_value                                            5.0000
# calculated_host_listings_count                                15.0000
# calculated_host_listings_count_entire_homes                   11.0000
# calculated_host_listings_count_private_rooms                   1.0000
# calculated_host_listings_count_shared_rooms                    0.0000
# reviews_per_month                                              2.8700
#
#                                                                   90%  \
# id                                           1150738330532524672.0000
# scrape_id                                         20240913025540.0000
# host_id                                                492305565.0000
# host_listings_count                                           63.0000
# host_total_listings_count                                     96.0000
# latitude                                                      34.5645
# longitude                                                    -96.7562
# accommodates                                                   8.0000
# bathrooms                                                      3.0000
# bedrooms                                                       4.0000
# beds                                                           5.0000
# minimum_nights                                                31.0000
# maximum_nights                                              1125.0000
# minimum_minimum_nights                                        31.0000
# maximum_minimum_nights                                        31.0000
# minimum_maximum_nights                                      1125.0000
# maximum_maximum_nights                                      1125.0000
# minimum_nights_avg_ntm                                        31.0000
# maximum_nights_avg_ntm                                      1125.0000
# calendar_updated                                                  NaN
# availability_30                                               30.0000
# availability_60                                               60.0000
# availability_90                                               90.0000
# availability_365                                             362.0000
# number_of_reviews                                            124.0000
# number_of_reviews_ltm                                         34.0000
# number_of_reviews_l30d                                         3.0000
# review_scores_rating                                           5.0000
# review_scores_accuracy                                         5.0000
# review_scores_cleanliness                                      5.0000
# review_scores_checkin                                          5.0000
# review_scores_communication                                    5.0000
# review_scores_location                                         5.0000
# review_scores_value                                            5.0000
# calculated_host_listings_count                                39.0000
# calculated_host_listings_count_entire_homes                   34.0000
# calculated_host_listings_count_private_rooms                   3.0000
# calculated_host_listings_count_shared_rooms                    0.0000
# reviews_per_month                                              3.9600
#
#                                                                   max
# id                                           1244148396592232448.0000
# scrape_id                                         20240913025540.0000
# host_id                                                651348256.0000
# host_listings_count                                         4680.0000
# host_total_listings_count                                   9019.0000
# latitude                                                      42.0222
# longitude                                                    -87.5284
# accommodates                                                  16.0000
# bathrooms                                                     50.0000
# bedrooms                                                      50.0000
# beds                                                         132.0000
# minimum_nights                                              1124.0000
# maximum_nights                                              3650.0000
# minimum_minimum_nights                                      1124.0000
# maximum_minimum_nights                                      1124.0000
# minimum_maximum_nights                                2147483647.0000
# maximum_maximum_nights                                2147483647.0000
# minimum_nights_avg_ntm                                      1124.0000
# maximum_nights_avg_ntm                                2147483647.0000
# calendar_updated                                                  NaN
# availability_30                                               30.0000
# availability_60                                               60.0000
# availability_90                                               90.0000
# availability_365                                             365.0000
# number_of_reviews                                           3689.0000
# number_of_reviews_ltm                                        666.0000
# number_of_reviews_l30d                                        60.0000
# review_scores_rating                                           5.0000
# review_scores_accuracy                                         5.0000
# review_scores_cleanliness                                      5.0000
# review_scores_checkin                                          5.0000
# review_scores_communication                                    5.0000
# review_scores_location                                         5.0000
# review_scores_value                                            5.0000
# calculated_host_listings_count                               569.0000
# calculated_host_listings_count_entire_homes                  569.0000
# calculated_host_listings_count_private_rooms                  89.0000
# calculated_host_listings_count_shared_rooms                   61.0000
# reviews_per_month                                             56.4600

# %%
raw_df.describe(include=['object']).T
# Out:
#                               count unique  \
# listing_url                   86295  86295
# last_scraped                  86295     11
# source                        86295      2
# name                          86294  83396
# description                   83816  72967
# neighborhood_overview         48031  37286
# picture_url                   86294  84095
# host_url                      86295  43340
# host_name                     86291  13365
# host_since                    86291   5283
# host_location                 67617   1476
# host_about                    49912  22422
# host_response_time            70406      4
# host_response_rate            70406     78
# host_acceptance_rate          71810    101
# host_is_superhost             83716      2
# host_thumbnail_url            86291  41985
# host_picture_url              86291  41985
# host_neighbourhood            73269   2008
# host_verifications            86291      9
# host_has_profile_pic          86291      2
# host_identity_verified        86291      2
# neighbourhood                 48033      2
# neighbourhood_cleansed        86295    497
# neighbourhood_group_cleansed  45533      3
# property_type                 86295    110
# room_type                     86295      4
# bathrooms_text                86241     60
# amenities                     86295  79448
# price                         72739   1963
# has_availability              81488      2
# calendar_last_scraped         86295     11
# first_review                  66855   4415
# last_review                   66855   2954
# license                       28912  18945
# instant_bookable              86295      2
# country                       86295      1
# state                         86295      3
# city                          86295      5
#
#                                                                             top  \
# listing_url                               https://www.airbnb.com/rooms/37853838
# last_scraped                                                         2024-09-05
# source                                                              city scrape
# name                          Wyndham Austin Resort|1BR/1BA King Bed w/ Gym&...
# description                   Keep it simple at this peaceful and centrally-...
# neighborhood_overview                   • CW Austin Resort is in Austin, Texas.
# picture_url                   https://a0.muscache.com/pictures/miso/Hosting-...
# host_url                            https://www.airbnb.com/users/show/107434423
# host_name                                                            Blueground
# host_since                                                           2016-12-16
# host_location                                                   Los Angeles, CA
# host_about                    We’re Blueground, a global proptech company wi...
# host_response_time                                               within an hour
# host_response_rate                                                         100%
# host_acceptance_rate                                                       100%
# host_is_superhost                                                             f
# host_thumbnail_url            https://a0.muscache.com/defaults/user_pic-50x5...
# host_picture_url              https://a0.muscache.com/defaults/user_pic-225x...
# host_neighbourhood                                                   Central LA
# host_verifications                                           ['email', 'phone']
# host_has_profile_pic                                                          t
# host_identity_verified                                                        t
# neighbourhood                                           Neighborhood highlights
# neighbourhood_cleansed                                                    78704
# neighbourhood_group_cleansed                                City of Los Angeles
# property_type                                                       Entire home
# room_type                                                       Entire home/apt
# bathrooms_text                                                           1 bath
# amenities                                                                    []
# price                                                                   $150.00
# has_availability                                                              t
# calendar_last_scraped                                                2024-09-05
# first_review                                                         2024-05-27
# last_review                                                          2024-09-02
# license                                                                  Exempt
# instant_bookable                                                              f
# country                                                           united_states
# state                                                                california
# city                                                                los_angeles
#
#                                freq
# listing_url                       1
# last_scraped                  38312
# source                        72755
# name                             41
# description                     259
# neighborhood_overview           116
# picture_url                      22
# host_url                       1263
# host_name                      1263
# host_since                     1279
# host_location                 19445
# host_about                     1263
# host_response_time            56911
# host_response_rate            54753
# host_acceptance_rate          23878
# host_is_superhost             49530
# host_thumbnail_url             2159
# host_picture_url               2159
# host_neighbourhood             3246
# host_verifications            66191
# host_has_profile_pic          84130
# host_identity_verified        76956
# neighbourhood                 48032
# neighbourhood_cleansed         2264
# neighbourhood_group_cleansed  22447
# property_type                 24694
# room_type                     67238
# bathrooms_text                39877
# amenities                       160
# price                          1177
# has_availability              81281
# calendar_last_scraped         38318
# first_review                    179
# last_review                    1860
# license                        2182
# instant_bookable              60193
# country                       86295
# state                         57879
# city                          45533

# %% [markdown]
# # Data cleansing

# %% [markdown]
# ## Adjust data types

# %%
# Numeric features
nm_features = ""
